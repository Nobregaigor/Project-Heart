# %% [markdown]
# # Tetrahedralize

# %%
from project_heart.lv import LV
import numpy as np
import pyvista as pv
pv.set_jupyter_backend("pythreejs")

import os
from pathlib import Path

from project_heart.enums import *

# %%
lv = LV.from_pyvista_read("../sample_files/lvtetmesh.vtk") # load reference mesh (can also be done from other methods)
lv.tetrahedralize(backend=TETRA_BACKEND.WILDMESHING, stop_quality=1000)
lv.plot(show_edges=True)
# Out:
# Renderer(camera=PerspectiveCamera(aspect=1.3333333333333333, children=(DirectionalLight(color='#fefefe', posit…

# %%
lv.mesh
# Out:
# UnstructuredGrid (0x12401fbde20)
#   N Cells:	17246
#   N Points:	5194
#   X Bounds:	-2.197e+01, 5.638e+01
#   Y Bounds:	-3.899e+01, 4.334e+01
#   Z Bounds:	-4.719e+01, 3.677e+01
#   N Arrays:	0

# %%
lv.mesh.save("../sample_files/lvtetmesh_verycoarse.vtk")

# %%
lv = LV.from_pyvista_read("../sample_files/lvtetmesh.vtk") # load reference mesh (can also be done from other methods)
lv.tetrahedralize(backend=TETRA_BACKEND.TETGEN, order=1, mindihedral=0.0, minratio=2.0)
lv.plot(show_edges=True)
# Out:
# Renderer(camera=PerspectiveCamera(aspect=1.3333333333333333, children=(DirectionalLight(color='#fefefe', posit…

# %%
lv.mesh
# Out:
# UnstructuredGrid (0x12404118460)
#   N Cells:	218359
#   N Points:	64452
#   X Bounds:	-2.198e+01, 5.639e+01
#   Y Bounds:	-3.899e+01, 4.336e+01
#   Z Bounds:	-4.722e+01, 3.682e+01
#   N Arrays:	0

# %%
lv.mesh.save("../sample_files/lvtetmesh_coarse.vtk")
